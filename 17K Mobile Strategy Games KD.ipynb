# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ad =pd.read_csv(r"C:\Users\dines\Downloads\17K Mobile Strategy Games\appstore_games.csv")

# %%
ad
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# ...

# %%
ad.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
ad.describe(include='all')
# Out:
#                                                       URL            ID  \
# count                                               17007  1.700700e+04
# unique                                              16847           NaN
# top     https://apps.apple.com/us/app/additions/id1432...           NaN
# freq                                                    2           NaN
# mean                                                  NaN  1.059614e+09
# std                                                   NaN  2.999676e+08
# min                                                   NaN  2.849214e+08
# 25%                                                   NaN  8.996543e+08
# 50%                                                   NaN  1.112286e+09
# 75%                                                   NaN  1.286983e+09
# max                                                   NaN  1.475077e+09
#
#              Name        Subtitle  \
# count       17007            5261
# ...

# %%
ad.head(5)
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
ad.drop(['In-app Purchases'], axis = 1, inplace=True)

# %%
ad.dropna(how ='any',inplace = True)

# %%
ad.isnull().sum()
# Out:
# URL                             0
# ID                              0
# Name                            0
# Subtitle                        0
# Icon URL                        0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# Description                     0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
ad['Icon URL'].isnull().sum()
# Out:
# 0

# %%
ad.head(5)
# Out:
#                                                   URL         ID  \
# 5   https://apps.apple.com/us/app/sudoku-classic-n...  286210009
# 19  https://apps.apple.com/us/app/cool-sudoku-jigs...  290614255
# 27  https://apps.apple.com/us/app/lux-touch-3-worl...  292538570
# 33  https://apps.apple.com/us/app/chess-tchess-pro...  295445501
# 36  https://apps.apple.com/us/app/chess-tchess-lit...  296756437
#
#                               Name                        Subtitle  \
# 5   Sudoku - Classic number puzzle         Original brain training
# 19     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  Lux Touch 3 - World Domination         Game of Global Conquest
# 33              Chess - tChess Pro  For beginners to professionals
# 36             Chess - tChess Lite             Fun and easy to use
#
#                                              Icon URL  Average User Rating  \
# 5   https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# ...

# %%
ad.drop(['URL'],axis = 1,inplace=True)

# %%
ad['Name'].isnull().sum()
# Out:
# 0

# %%
ad.head(5)
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#                                              Icon URL  Average User Rating  \
# 5   https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 19  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 27  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 33  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 36  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
#
#     User Rating Count  Price  \
# ...

# %%
ad.dropna(how ='any',inplace = True)

# %%
ad.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Subtitle                        0
# Icon URL                        0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# Description                     0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2714 entries, 5 to 16993
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            2714 non-null   int64
#  1   Name                          2714 non-null   object
#  2   Subtitle                      2714 non-null   object
#  3   Icon URL                      2714 non-null   object
#  4   Average User Rating           2714 non-null   float64
#  5   User Rating Count             2714 non-null   float64
#  6   Price                         2714 non-null   float64
#  7   Description                   2714 non-null   object
#  8   Developer                     2714 non-null   object
#  9   Age Rating                    2714 non-null   object
#  10  Languages                     2714 non-null   object
#  11  Size                          2714 non-null   float64
# ...

# %%
ad.head()
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#                                              Icon URL  Average User Rating  \
# 5   https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 19  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 27  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 33  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 36  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
#
#     User Rating Count  Price  \
# ...

# %%
ad.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Subtitle                        0
# Icon URL                        0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# Description                     0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
ad.dtypes
# Out:
# ID                                int64
# Name                             object
# Subtitle                         object
# Icon URL                         object
# Average User Rating             float64
# User Rating Count               float64
# Price                           float64
# Description                      object
# Developer                        object
# Age Rating                       object
# Languages                        object
# Size                            float64
# Primary Genre                    object
# Genres                           object
# Original Release Date            object
# Current Version Release Date     object
# dtype: object

# %%
ad['Age Rating'].unique()
# Out:
# array(['4+', '9+', '17+', '12+'], dtype=object)

# %%
ad.drop(['Icon URL'],axis = 1 , inplace=True)

# %%
ad.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Subtitle                        0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# Description                     0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
ad.head()
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0   0.00
# 19                  3.5              357.0   0.00
# 27                  3.5            72428.0   0.00
# 33                  4.0             3062.0   7.99
# 36                  3.5             5488.0   0.99
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# ...

# %%
ad.ID
# Out:
# 5         286210009
# 19        290614255
# 27        292538570
# 33        295445501
# 36        296756437
#             ...
# 16932    1472818549
# 16950    1473084135
# 16962    1473559573
# 16967    1473680543
# 16993    1474461379
# Name: ID, Length: 2714, dtype: int64

# %%
ad['ID'].unique()
# Out:
# array([ 286210009,  290614255,  292538570, ..., 1473559573, 1473680543,
#        1474461379], dtype=int64)

# %%
ad.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Subtitle                        0
# Average User Rating             0
# User Rating Count               0
# Price                           0
# Description                     0
# Developer                       0
# Age Rating                      0
# Languages                       0
# Size                            0
# Primary Genre                   0
# Genres                          0
# Original Release Date           0
# Current Version Release Date    0
# dtype: int64

# %%
ad_ID=lambda x:str(x).split('/')[0]
ad.ID=ad.ID.apply(ad_ID)
ad['ID'].head()
# Out:
# 5     286210009
# 19    290614255
# 27    292538570
# 33    295445501
# 36    296756437
# Name: ID, dtype: object

# %%
ad.head(5)
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0   0.00
# 19                  3.5              357.0   0.00
# 27                  3.5            72428.0   0.00
# 33                  4.0             3062.0   7.99
# 36                  3.5             5488.0   0.99
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# ...

# %%
ad.Size
# Out:
# 5         48672768.0
# 19        52236288.0
# 27        55071744.0
# 33         7517184.0
# 36         5874688.0
#             ...
# 16932     44067840.0
# 16950    151308288.0
# 16962    125348864.0
# 16967    128687104.0
# 16993      8845312.0
# Name: Size, Length: 2714, dtype: float64

# %%
ad['Size'].unique()
# Out:
# array([4.86727680e+07, 5.22362880e+07, 5.50717440e+07, ...,
#        1.25348864e+08, 1.28687104e+08, 8.84531200e+06])

# %%
ad['Size']=ad['Size'].astype(str)
ad['Size']=ad['Size'].apply(lambda x:x.replace(',','.'))
ad['Size']=ad['Size'].astype(float)
ad['Size'].head()
# Out:
# 5     48672768.0
# 19    52236288.0
# 27    55071744.0
# 33     7517184.0
# 36     5874688.0
# Name: Size, dtype: float64

# %%
ad['Size']=ad['Size'].astype(str)
ad['Size']=ad['Size'].apply(lambda x: x.replace(',','.'))
ad['Size']=ad['Size'].apply(lambda x: x/2)
ad['Size'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 ad['Size']=ad['Size'].astype(str)
#       2 ad['Size']=ad['Size'].apply(lambda x: x.replace(',','.'))
# ----> 3 ad['Size']=ad['Size'].apply(lambda x: x/2)
#       4 ad['Size'].head()
#
# File F:\Users\dines\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
# ...

# %%
ad.head(5)
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0   0.00
# 19                  3.5              357.0   0.00
# 27                  3.5            72428.0   0.00
# 33                  4.0             3062.0   7.99
# 36                  3.5             5488.0   0.99
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# ...

# %%
ad.shape
# Out:
# (2714, 15)

# %%
ad.size
# Out:
# 40710

# %%
ad.describe()
# Out:
#        Average User Rating  User Rating Count        Price
# count          2714.000000       2.714000e+03  2714.000000
# mean              4.245394       7.021117e+03     0.568648
# std               0.643109       6.950938e+04     3.373456
# min               1.000000       5.000000e+00     0.000000
# 25%               4.000000       1.625000e+01     0.000000
# 50%               4.500000       9.150000e+01     0.000000
# 75%               4.500000       8.307500e+02     0.000000
# max               5.000000       3.032734e+06   139.990000

# %%
ad.duplicated()
# Out:
# 5        False
# 19       False
# 27       False
# 33       False
# 36       False
#          ...
# 16932    False
# 16950    False
# 16962    False
# 16967    False
# 16993    False
# Length: 2714, dtype: bool

# %%
ad.head(2)
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0    0.0
# 19                  3.5              357.0    0.0
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# 19  You can now play Sudoku, Killer Sudoku, Jigsaw...  Splash Software Ltd.
#
#    Age Rating Languages        Size Primary Genre  \
# 5          4+        EN  48672768.0         Games
# 19         4+        EN  52236288.0         Games
#
#                                     Genres Original Release Date  \
# 5   Games, Entertainment, Strategy, Puzzle            30/07/2008
# ...

# %%
fig, ax = plt.subplots(figsize=(10,15))
sns.countplot(x='User Rating Count',data=ad,ax=ax)
for i in ax.countplot:
    ax.bar_label(i)
plt.title('User Rating')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 3
#       1 fig, ax = plt.subplots(figsize=(10,15))
#       2 sns.countplot(x='User Rating Count',data=ad,ax=ax)
# ----> 3 for i in ax.countplot:
#       4     ax.bar_label(i)
#       5 plt.title('User Rating')
#
# AttributeError: 'Axes' object has no attribute 'countplot'

# %%
ad['Size'].value_counts()[:].plot(kind='line',figsize=(11,5),color='red',title='game Size').grid(color = 'blue', linestyle = '--', linewidth = 1)

# %%
ad.head(5)
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0   0.00
# 19                  3.5              357.0   0.00
# 27                  3.5            72428.0   0.00
# 33                  4.0             3062.0   7.99
# 36                  3.5             5488.0   0.99
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# ...

# %%
a=ad['Subtitle'].unique()
print(a)
print("---------------------------------")
b= ad['Price'].min()
print(b)
# Out:
# ['Original brain training' 'Sudoku, Jigsaw, Killer, Kakuro'
#  'Game of Global Conquest' ... 'Develop Your Car Racing Inc'
#  'Best 2 player air hockey game' 'Simple & elegant chess clock']
# ---------------------------------
# 0.0

# %%
ad['Price'].value_counts()
# Out:
# Price
# 0.00      2345
# 0.99        80
# 2.99        69
# 1.99        68
# 4.99        65
# 3.99        40
# 9.99        18
# 6.99        11
# 5.99         4
# 8.99         4
# 7.99         3
# 11.99        2
# 19.99        1
# 139.99       1
# 16.99        1
# 36.99        1
# 59.99        1
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x ='User Rating Count',data = ad,palette='rainbow')
plt.title('demo')
plt.show()
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_8844\445569893.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x ='User Rating Count',data = ad,palette='rainbow')

# %%
fig = plt.figure(figsize=(10,7))
ax=fig.gca()
sns.boxplot(x=ad['User Rating Count'], y=ad['Average User Rating'])
plt.show()

# %%
sns.violinplot(x=ad['User Rating Count'], y =ad['Average User Rating'])
plt.show()

# %%
ad['Size'].value_counts()[:20].plot(kind='bar', figsize=(20,8))
plt.title('Game Size')
# Out:
# Text(0.5, 1.0, 'Game Size')

# %%
ad.head()
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# 27  292538570  Lux Touch 3 - World Domination         Game of Global Conquest
# 33  295445501              Chess - tChess Pro  For beginners to professionals
# 36  296756437             Chess - tChess Lite             Fun and easy to use
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0   0.00
# 19                  3.5              357.0   0.00
# 27                  3.5            72428.0   0.00
# 33                  4.0             3062.0   7.99
# 36                  3.5             5488.0   0.99
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x=ad['Size'],y =ad['Average User Rating'])
plt.show()

# %%
ad['Original Release Date'].value_counts()[:10].plot(kind='bar', figsize=(10,9))
plt.title('Release Date')

ad['Current Version Release Date'].value_counts()[:10].plot(kind='bar', figsize=(10,6))
plt.title('updeat Date')
# Out:
# Text(0.5, 1.0, 'updeat Date')

# %%
ad['Current Version Release Date'].value_counts().plot(kind='line', figsize=(10,10))
plt.title('Current Version Date updeat')
# Out:
# Text(0.5, 1.0, 'Current Version Date updeat')

# %%
sns.countplot(ad['Size'])
sns.countplot(ad['Size']).set_xticklabels(sns.countplot(ad['Size']).get_xticklabels(),rotation=1125)
fig = plt.gcf()
fig.set_size_inches(10,8)
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_8844\342620784.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.countplot(ad['Size']).set_xticklabels(sns.countplot(ad['Size']).get_xticklabels(),rotation=1125)

# %%
ad.tail(5)
# Out:
#                ID                      Name                       Subtitle  \
# 16932  1472818549  Spatula: TFT Cheat Sheet  TFT Items and Champion Helper
# 16950  1473084135                  Die Last                Who can survive
# 16962  1473559573        Idle Racing Tycoon    Develop Your Car Racing Inc
# 16967  1473680543        Glow Hockey Strike  Best 2 player air hockey game
# 16993  1474461379     Agadmator Chess Clock   Simple & elegant chess clock
#
#        Average User Rating  User Rating Count  Price  \
# 16932                  5.0               11.0    0.0
# 16950                  3.0                6.0    0.0
# 16962                  5.0               51.0    0.0
# 16967                  5.0                5.0    0.0
# 16993                  5.0               33.0    0.0
#
#                                              Description      Developer  \
# 16932  Did you ever get confused while playing TeamFi...  Murilo Bastos
# ...

# %%
ad.hist(figsize=(20,22),color='blue')
# Out:
# array([[<Axes: title={'center': 'Average User Rating'}>,
#         <Axes: title={'center': 'User Rating Count'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >]], dtype=object)

# %%
ad.head(2)
# Out:
#            ID                            Name                        Subtitle  \
# 5   286210009  Sudoku - Classic number puzzle         Original brain training
# 19  290614255     Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
#
#     Average User Rating  User Rating Count  Price  \
# 5                   3.0               47.0    0.0
# 19                  3.5              357.0    0.0
#
#                                           Description             Developer  \
# 5   Sudoku will tease your brain, challenge you or...       OutOfTheBit Ltd
# 19  You can now play Sudoku, Killer Sudoku, Jigsaw...  Splash Software Ltd.
#
#    Age Rating Languages        Size Primary Genre  \
# 5          4+        EN  48672768.0         Games
# 19         4+        EN  52236288.0         Games
#
#                                     Genres Original Release Date  \
# 5   Games, Entertainment, Strategy, Puzzle            30/07/2008
# ...

# %%
sns.pairplot(ad)
